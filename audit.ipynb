# %%
import lxml.etree as ET
from collections import defaultdict
import re

OSMFILE = "phoenix_arizona.osm" 
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", "Way", "Trail", "Parkway", "Commons", "Circle", "Terrace", "Highway"]

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def audit_street(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                # if the tag is a street
                if tag.attrib['k'] == "addr:street":
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

# %%
audit_street(OSMFILE)
# Out:
# defaultdict(set,
#             {'1': {'S Yavapai Rd #1'},
#              '100': {'East Elwood Street Suite 100'},
#              '101': {'East Baseline Road Suite 101',
#               'N 27th Ave Ste 101',
#               'N John Wayne Parkway #101'},
#              '102': {'North 93rd Avenue #102',
#               'North Power Road #102',
#               'W Lake Pleasant Pkwy # 102'},
#              '103': {'E Greenway Pkwy #103'},
#              '104': {'E Valley Auto Dr #104', 'S Signal Butte Rd #104'},
#              '105': {'E Ocotillo Rd Bldg 105',
#               'N Scottsdale Rd #105',
#               'North 90th Street #105'},
#              '110': {'E 5th Ave #110', 'East Doubletree Ranch Road #110'},
#              '111': {'N Gilbert Rd #111'},
#              '114-225': {'South Higley Road, Suite 114-225'},
#              '117': {'N 51st Ave #117'},
#              '119': {'N. Gilbert Road, #119'},
#              '121': {'3514 N. Power Road, Ste. 121'},
#              '122': {'E Baseline Rd Ste 122'},
#              '130': {'7077 E Marilyn Rd, Suite 130',
#               'E. Marilyn Rd., Bldg. 4, Suite 130'},
#              '133': {'West Indian School Road #133'},
#              '148': {'S 48th St #148'},
#              '15935': {'E Thomas Road #15935'},
#              '170-A': {'E. Chandler Blvd. #170-A'},
#              '18': {'S Alma School Rd #18'},
#              '2': {'N Stapley Dr #2'},
#              '200': {'East Elwood Street Suite 200',
#               'East Greenway Rd, #200',
#               'East Marilyn Road Building 4 Suite 200',
#               'N Arboleda, Suite 200',
#               'W Union Hills Dr., Building D, Suite 200'},
#              '201': {'E Williams Field Rd #201',
#               'N Arboleda, Suite 201',
#               'West Ray Road, Suite 201'},
#              '202': {'N Dysart Rd #202'},
#              '21': {'N 32nd St Lot 21'},
#              '210': {'N. Hayden Road, Suite 210'},
#              '221': {'S. Stapley Dr. Suite 221'},
#              '238': {'West Highway 238'},
#              '270': {'East Washington Street Suite 270'},
#              '287': {'East Highway 287'},
#              '290': {'N. 83rd Ave., Ste 290'},
#              '3': {'E Thomas Rd #3', 'N Arizona Ave #3'},
#              '300': {'Doubletree Ranch Rd. Suite 300',
#               'N 24th Street Suite 300'},
#              '3031': {'Tatum Blvd. Suite 3031'},
#              '350': {'N. 85th Street #350'},
#              '401': {'North 27th Avenue #401'},
#              '41': {'South Rogers #41'},
#              '42': {'South Rogers #42'},
#              '5': {'North 51st Avenue Suite #134 Building 5'},
#              '540-132': {'E. Indian School Road, Suite 540-132'},
#              '60': {'East US Highway 60'},
#              '605': {'West Happy Valley Road, Suite #141 - 605'},
#              '68': {'BIA Route 68'},
#              '85': {'MC 85', 'South Highway 85', 'West MC 85'},
#              '900': {'Rio Salado Parkway #900'},
#              'A': {'East Pecos Road, Suite A'},
#              'A-110': {'North 28th Drive, Suite A-110'},
#              'A-115': {'9700 N. 91st St., Suite A-115'},
#              'A109-187': {'East Baseline Road A109-187'},
#              'A6': {'S Rural Rd #A6'},
#              'Alamos': {'North Los Alamos'},
#              'Alba': {'North Alba'},
#              'Apartment': {'East Apartment'},
#              'ArizonamAvenue': {'South ArizonamAvenue'},
#              'Av': {'N 28th Av'},
#              'Ave': {'1701 E Southern Ave',
#               'E Garnet Ave',
#               'E Southern Ave',
#               'E Terrace Ave',
#               'E. Posada Ave',
#               'N 174th Ave',
#               'N 1st Ave',
#               'N 45th Ave',
#               'N College Ave',
#               'N Del Cambre Ave',
#               'North Arizona Ave',
#               'Noth Central Ave',
#               'S 49th Ave',
#               'S Buena Vista Ave',
#               'S Central Ave',
#               'S Farmer Ave',
#               'South Forest Ave',
#               'South Longmore Ave',
#               'W Grand Ave',
#               'W Peoria Ave',
#               'W. Vineyard Ave',
#               'West Grove Ave'},
#              'Ave,': {'Casey Ave,'},
#              'Ave.': {'E. Devonshire Ave.'},
#              'B102': {'S Ellsworth Rd #B102'},
#              'B119': {'East Pinnacle Peak Road #B119'},
#              'Bend': {'East Indian Bend'},
#              'Beverly': {'South Beverly'},
#              'Blvd': {'1900 West Chandler Blvd',
#               'E Chandler Blvd',
#               'E Golden Eagle Blvd',
#               'E Shea Blvd',
#               'N Saguaro Blvd',
#               'N. Fountain Hills Blvd',
#               'North Tatum Blvd',
#               'Tatum Blvd'},
#              'Blvd.': {'Apache Blvd.', 'N. Saguaro Blvd.'},
#              'Boulavard': {'North Avondale Boulavard'},
#              'C102': {'S Mesa Drive Suite C102'},
#              'Camelback': {'W. Camelback'},
#              'Campo': {'Via Del Campo'},
#              'Center': {'West Arrowhead Towne Center'},
#              'Cheshire': {'South Cheshire'},
#              'Chestnut': {'South Chestnut'},
#              'Commercio': {'East Via De Commercio'},
#              'Crossing': {'North Cotton Crossing'},
#              'Ctr': {'W Arrowhead Towne Ctr'},
#              'D107-108': {'North 7th Street #D107-108'},
#              'Date': {'North Date'},
#              'Davis': {'S Davis'},
#              'Dobson': {'South Dobson'},
#              'Dr': {'E Del Timbre Dr',
#               'E Rancho Vista Dr',
#               'E San Salvador Dr',
#               'N La Montana Dr',
#               'S Val Vista Dr',
#               'W St kateri Dr',
#               'W Union Hills Dr',
#               'West Wagner Complex Dr'},
#              'Dr.': {'E. Davenport Dr.'},
#              'E108': {'W Bell Rd #E108'},
#              'East': {'North Metro Park East', 'North Village Drive East'},
#              'Emerson': {'South Emerson'},
#              'Estrella': {'East Via Estrella'},
#              'F6': {'West Orion Street Suite F6'},
#              'Fountains': {'East Avenue of the Fountains'},
#              'Freeway': {'West Papago Freeway'},
#              'Glen': {'North 25th Glen'},
#              'Grand': {'North Grand'},
#              'Hall': {'South Hall'},
#              'Horne': {'North Horne'},
#              'Ki': {'W. Gu u Ki'},
#              'Lewis': {'North Lewis', 'South Lewis'},
#              'Linda': {'East Via Linda'},
#              'Ln': {'E Irma Ln'},
#              'Longmore': {'South Longmore'},
#              'Loop': {'East Rose Garden Loop', 'North Greenway Hayden Loop'},
#              'MacDonald': {'North MacDonald'},
#              'Macdonald': {'South Macdonald'},
#              'Mall': {'East Lemon Mall',
#               'East Orange Mall',
#               'East Tyler Mall',
#               'South Cady Mall',
#               'South Forest Mall'},
#              'Markdale': {'North Markdale'},
#              'Mountain': {'North Red Mountain'},
#              'Norte': {'West Calle del Norte'},
#              'North': {'East Paradise Village Parkway North'},
#              'Oro': {'West Camino de Oro'},
#              'Park': {'East Gammage Park'},
#              'Parkwway': {'North Coyote Lakes Parkwway'},
#              'Pasadena': {'North Pasadena'},
#              'Phoenix': {'Glendale, Phoenix'},
#              'Pima': {'North Pima'},
#              'Pkwy': {'East Rio Salado Pkwy'},
#              'Pl': {'E Havasu Pl', 'West Morelos Pl'},
#              'Plaza': {'North Civic Center Plaza'},
#              'Point': {'North Sunrise Point'},
#              'Q102': {'S Mill Ave #Q102'},
#              'RD': {'E. Brown RD'},
#              'Rd': {'E Baseline Rd',
#               'E Camelback Rd',
#               'E Warner Rd',
#               'E. Elliot Rd',
#               'East Williamsfield Rd',
#               'N Fort McDowell Rd',
#               'N Hayden Rd',
#               'N Maricopa Rd',
#               'N Scottsdale Rd',
#               'S Coronado Rd',
#               'S Watson Rd',
#               'South MIller Rd',
#               'W Broadway Rd',
#               'W Elliot Rd',
#               'W. Indian School Rd',
#               'West Happy Valley Rd'},
#              'Rd.': {'5810 Alameda Rd.',
#               'East Chandler Heights Rd.',
#               'N. Cave Creek Rd.',
#               'West Happy Vally Rd.'},
#              'Reyes': {'South Reyes'},
#              'Road)': {'South Velda Rose Road (I-17 Frontage Road)'},
#              'Roca': {'N Roca'},
#              'Rogers': {'South Rogers'},
#              'Rosa': {'West Calle Rosa'},
#              'Saguaro': {'South Camino Saguaro'},
#              'Sirrine': {'South Sirrine'},
#              'Sol': {'North Camino del Sol', 'West Camino del Sol'},
#              'South': {'East Sky Harbor Circle South',
#               'North Paradise Village Parkway South'},
#              'Spruce': {'South Spruce'},
#              'St': {'E. Frontier St',
#               'N 16th St',
#               'S 24th St',
#               'W 18th St',
#               'W Main St',
#               'W McNeil St'},
#              'St.': {'N. 120th St.', 'N. 158th St.'},
#              'Start': {'Start'},
#              'Suite': {'E. Warner Rd Suite'},
#              'Sunnyvale': {'South Sunnyvale'},
#              'Sur': {'North Via Paseo del Sur'},
#              'Sycamore': {'North Sycamore'},
#              'Taliesin': {'North Taliesin'},
#              'Valencia': {'South Valencia'},
#              'Ventura': {'East Via de Ventura'},
#              'Vista': {'North Loma Vista'},
#              'Watermelon': {'Watermelon'},
#              'West': {'Desert Breeze Boulevard West',
#               'North Metro Park West',
#               'North Paradise Village Parkway West',
#               'South Seville Boulevard West'},
#              'Westwood': {'North Westwood', 'South Westwood'},
#              'Windsor': {'Windsor'},
#              'World': {'Leisure World'},
#              'Yaqui': {'South Avenida del Yaqui'},
#              'juncion': {'valvsta,apache juncion'},
#              'rd': {'West McDowell rd'},
#              'street': {'South Wall street'}})

# %%
mapping = { "St": "Street",
            "St.": "Street",
            "street": "Street",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Boulavard": "Boulevard",
            "Rd": "Road",
            "Rd.": "Road",
            "RD": "Road",
            "Pl": "Place",
            "Pl.": "Place",
            "PKWY": "Parkway",
            "Pkwy": "Parkway",
            "Ln": "Lane",
            "Ln.": "Lane",
            "Dr": "Drive",
            "Dr.": "Drive"
            }

def fix_street(osmfile):
    st_types = audit_street(osmfile)
    for st_type, ways in st_types.iteritems():
        for name in ways:
            if st_type in mapping:
                better_name = name.replace(st_type, mapping[st_type])
                print name, "=>", better_name

# %%
fix_street(OSMFILE)
# Out:
# E. Brown RD => E. Brown Road
# East Rio Salado Pkwy => East Rio Salado Parkway
# West Happy Valley Rd => West Happy Valley Road
# W Broadway Rd => W Broadway Road
# W Elliot Rd => W Elliot Road
# East Williamsfield Rd => East Williamsfield Road
# W. Indian School Rd => W. Indian School Road
# E. Elliot Rd => E. Elliot Road
# South MIller Rd => South MIller Road
# N Fort McDowell Rd => N Fort McDowell Road
# N Hayden Rd => N Hayden Road
# S Coronado Rd => S Coronado Road
# S Watson Rd => S Watson Road
# E Warner Rd => E Warner Road
# N Scottsdale Rd => N Scottsdale Road
# N Maricopa Rd => N Maricopa Road
# E Baseline Rd => E Baseline Road
# E Camelback Rd => E Camelback Road
# South Wall street => South Wall Street
# East Chandler Heights Rd. => East Chandler Heights Road
# 5810 Alameda Rd. => 5810 Alameda Road
# N. Cave Creek Rd. => N. Cave Creek Road
# West Happy Vally Rd. => West Happy Vally Road
# E Havasu Pl => E Havasu Place
# West Morelos Pl => West Morelos Place
# E. Devonshire Ave. => E. Devonshire Avenue
# N. 120th St. => N. 120th Street
# N. 158th St. => N. 158th Street
# Apache Blvd. => Apache Boulevard
# N. Saguaro Blvd. => N. Saguaro Boulevard
# W 18th St => W 18th Street
# S 24th St => S 24th Street
# W Main St => W Main Street
# N 16th St => N 16th Street
# W McNeil St => W McNeil Street
# E. Frontier St => E. Frontier Street
# E Terrace Ave => E Terrace Avenue
# S Buena Vista Ave => S Buena Vista Avenue
# S Central Ave => S Central Avenue
# S 49th Ave => S 49th Avenue
# N 45th Ave => N 45th Avenue
# North Arizona Ave => North Arizona Avenue
# W. Vineyard Ave => W. Vineyard Avenue
# N 1st Ave => N 1st Avenue
# E. Posada Ave => E. Posada Avenue
# N College Ave => N College Avenue
# South Longmore Ave => South Longmore Avenue
# N Del Cambre Ave => N Del Cambre Avenue
# South Forest Ave => South Forest Avenue
# S Farmer Ave => S Farmer Avenue
# W Peoria Ave => W Peoria Avenue
# West Grove Ave => West Grove Avenue
# W Grand Ave => W Grand Avenue
# 1701 E Southern Ave => 1701 E Southern Avenue
# E Garnet Ave => E Garnet Avenue
# E Southern Ave => E Southern Avenue
# Noth Central Ave => Noth Central Avenue
# N 174th Ave => N 174th Avenue
# E Irma Ln => E Irma Lane
# E. Davenport Dr. => E. Davenport Drive
# E San Salvador Dr => E San Salvador Drive
# W Union Hills Dr => W Union Hills Drive
# N La Montana Dr => N La Montana Drive
# E Del Timbre Dr => E Del Timbre Drive
# E Rancho Vista Dr => E Rancho Vista Drive
# West Wagner Complex Dr => West Wagner Complex Drive
# W St kateri Dr => W St kateri Drive
# S Val Vista Dr => S Val Vista Drive
# North Avondale Boulavard => North Avondale Boulevard
# N. Fountain Hills Blvd => N. Fountain Hills Boulevard
# Tatum Blvd => Tatum Boulevard
# E Golden Eagle Blvd => E Golden Eagle Boulevard
# N Saguaro Blvd => N Saguaro Boulevard
# North Tatum Blvd => North Tatum Boulevard
# 1900 West Chandler Blvd => 1900 West Chandler Boulevard
# E Chandler Blvd => E Chandler Boulevard
# E Shea Blvd => E Shea Boulevard

# %%
def audit_city(filename):
    osm_file = open(filename, "r")  
    city_list = set()
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if tag.attrib['k'] == "addr:city" and tag.attrib['v'] != "Phoenix":
                    city_list.add(tag.attrib['v'])
    return city_list

# %%
other_city = audit_city(OSMFILE)
print len(other_city)
print other_city
# Out:
# 79
# set(['El Mirage', 'Gila Bend', 'Coolidge', 'Richland', 'Maricopa', 'Phenix', 'Anthem', 'Fort McDowell', 'Guadalupe', 'Golbert', 'Carefree', 'Sacaton', 'casa Grande', 'Morristown', 'Glemdale', 'tEMPE', '2036 N. Gilbert Rd.', 'Paradise Valley, AZ', 'Surprise', 'Gilbert', 'Mayer', 'Goodyear', 'Sun City West', 'Laveen', 'mesa', 'Rio Verde', 'Phoenx', 'PHoenix', 'Tempe', 'Avondale', 'Luke AFB, Waddell', 'Laveen Village', 'Peoria', 'San Diego', 'Apache Junction', 'Scottsdale', 'Chandler', 'Queen Creek', 'Tonopah', 'Sun Lakes', 'SunLakes', 'Arlington', 'Vulture City', 'Mesa', 'sun City West', 'Desert Hills', 'Higley', 'Fountain Hills', 'Luke AFB', 'Maricopaaricopa', 'tempe', '25', 'Mobile', 'peoria', 'Wickenburg', 'Litchfield Park', 'scottsdale', 'Paradise Valley', 'Gold Canyon', 'SanTan Valley', 'Glendale', 'MEsa', 'Tollenson', 'Black Canyon City', 'Sun City', 'Tolleson', 'Cave Creek', 'San Tan Valley', 'Mesa, AZ', 'Rock Springs', 'Eloy', 'New River', 'Tohono Oodham', 'Buckeye', 'Casa Grande', 'Florence', 'CHANDLER', 'Wittmann', 'Queen Valley'])
